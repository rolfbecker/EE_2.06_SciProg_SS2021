# %% [markdown]
# # Exercises on Numpy, Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ex. 1: Read, **understand** and execute the following code.

# %%
x = np.arange(-5,5.01,0.2)

# %%
x
# Out:
# array([-5.0000000e+00, -4.8000000e+00, -4.6000000e+00, -4.4000000e+00,
#        -4.2000000e+00, -4.0000000e+00, -3.8000000e+00, -3.6000000e+00,
#        -3.4000000e+00, -3.2000000e+00, -3.0000000e+00, -2.8000000e+00,
#        -2.6000000e+00, -2.4000000e+00, -2.2000000e+00, -2.0000000e+00,
#        -1.8000000e+00, -1.6000000e+00, -1.4000000e+00, -1.2000000e+00,
#        -1.0000000e+00, -8.0000000e-01, -6.0000000e-01, -4.0000000e-01,
#        -2.0000000e-01,  4.4408921e-15,  2.0000000e-01,  4.0000000e-01,
#         6.0000000e-01,  8.0000000e-01,  1.0000000e+00,  1.2000000e+00,
#         1.4000000e+00,  1.6000000e+00,  1.8000000e+00,  2.0000000e+00,
#         2.2000000e+00,  2.4000000e+00,  2.6000000e+00,  2.8000000e+00,
#         3.0000000e+00,  3.2000000e+00,  3.4000000e+00,  3.6000000e+00,
#         3.8000000e+00,  4.0000000e+00,  4.2000000e+00,  4.4000000e+00,
#         4.6000000e+00,  4.8000000e+00,  5.0000000e+00])

# %%
x2 = np.array([-5,0,5])

# %%
x3 = np.linspace(-5,5,11)

# %%
print("min(x)=%5.2f" % min(x))
print("min(x)=%5.2f" % min(x))
print("max(x)=%5.2f" % max(x))
print("max(x)=", max(x))
# Out:
# min(x)=-5.00
# min(x)=-5.00
# max(x)= 5.00
# max(x)= 5.000000000000009

# %% [markdown]
# ### 3rd Degree Polynomial with one Parameter

# %% [markdown]
# Let discuss the function
#
# $$ y = x^3 + ax + b$$

# %%
def y(x,a=0,b=0):
    return x**3+a*x + b

# %%
y1=y(x)
y2=y(x,-10)
y3=y(x,-20)
# print(f"y1:{y1:8.2f} , y2:{y2:8.2f} , y3:{y3:8.2f}")

# %%
print(y1)
# Out:
# [-1.2500000e+02 -1.1059200e+02 -9.7336000e+01 -8.5184000e+01
#  -7.4088000e+01 -6.4000000e+01 -5.4872000e+01 -4.6656000e+01
#  -3.9304000e+01 -3.2768000e+01 -2.7000000e+01 -2.1952000e+01
#  -1.7576000e+01 -1.3824000e+01 -1.0648000e+01 -8.0000000e+00
#  -5.8320000e+00 -4.0960000e+00 -2.7440000e+00 -1.7280000e+00
#  -1.0000000e+00 -5.1200000e-01 -2.1600000e-01 -6.4000000e-02
#  -8.0000000e-03  8.7581154e-44  8.0000000e-03  6.4000000e-02
#   2.1600000e-01  5.1200000e-01  1.0000000e+00  1.7280000e+00
#   2.7440000e+00  4.0960000e+00  5.8320000e+00  8.0000000e+00
#   1.0648000e+01  1.3824000e+01  1.7576000e+01  2.1952000e+01
#   2.7000000e+01  3.2768000e+01  3.9304000e+01  4.6656000e+01
#   5.4872000e+01  6.4000000e+01  7.4088000e+01  8.5184000e+01
#   9.7336000e+01  1.1059200e+02  1.2500000e+02]

# %%
print("y1:{y1}")
print(f"y1:{y1}")
#print(f"y1:{y1:8.2f}")
#print(f"y1:{y1:8.2g}")
# Out:
# y1:{y1}
# y1:[-1.2500000e+02 -1.1059200e+02 -9.7336000e+01 -8.5184000e+01
#  -7.4088000e+01 -6.4000000e+01 -5.4872000e+01 -4.6656000e+01
#  -3.9304000e+01 -3.2768000e+01 -2.7000000e+01 -2.1952000e+01
#  -1.7576000e+01 -1.3824000e+01 -1.0648000e+01 -8.0000000e+00
#  -5.8320000e+00 -4.0960000e+00 -2.7440000e+00 -1.7280000e+00
#  -1.0000000e+00 -5.1200000e-01 -2.1600000e-01 -6.4000000e-02
#  -8.0000000e-03  8.7581154e-44  8.0000000e-03  6.4000000e-02
#   2.1600000e-01  5.1200000e-01  1.0000000e+00  1.7280000e+00
#   2.7440000e+00  4.0960000e+00  5.8320000e+00  8.0000000e+00
#   1.0648000e+01  1.3824000e+01  1.7576000e+01  2.1952000e+01
#   2.7000000e+01  3.2768000e+01  3.9304000e+01  4.6656000e+01
#   5.4872000e+01  6.4000000e+01  7.4088000e+01  8.5184000e+01
#   9.7336000e+01  1.1059200e+02  1.2500000e+02]

# %%
print(int("30") + 60)
# print(30 + 60)
# Out:
# 90

# %%
print("30.1" + str(50))
print(float(30.1) + 50)
# Out:
# 30.150
# 80.1

# %%
def g(x,a=1):
    return a*x

# %%
import matplotlib.pyplot as plt

# %%
fig1, ax1 = plt.subplots(1,1,figsize=(6,4),dpi=136)
ax1.plot(x,y1)
#ax1.plot(x,y2)
ax1.plot(x,y3)
ax1.plot(x,g(x,-20))
ax1.set_xlabel("$x$")
ax1.set_ylabel("$y$")
ax1.set_title("Curve Comparison")
ax1.grid(True)
#"$y_2(x)=x^3-10x$", 

ax1.legend(["$y_1(x)=x^3$", "$y_3(x)=x^3-20x$","$g(x)=-20x$"])

plt.show()
fig1.savefig("fig1.png")

# %% [markdown]
# ### Discussion
#
# $$ \lim_{x\rightarrow \infty} f(x) = \infty $$
#
#
# $$
# \mathrm{point\;symmetric}: f(-x) = -f(x) \\
# \mathrm{local\;extrema}
# $$

# %% [markdown]
# ## Some fundamental purely python data types and data structures or containers
#
# * list
# * tuple
# * dict

# %%
miniList = ["Hello", "HSRW","!"]

# %%
myList = [8, "bla", miniList]
myTuple = (8, "bla", miniList)

# %%
myList
# Out:
# [8, 'bla', ['Hello', 'HSRW', '!']]

# %%
myTuple[1] = 333
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-298-77bb32e84130> in <module>
# ----> 1 myTuple[1] = 333
#
# TypeError: 'tuple' object does not support item assignment

# %%
myLen = len(myList) - 1 # Number of elements in list

# %%
idx = -1
elt = myList[idx]
print(f"idx: {idx}")
print(f"elt: {elt}")
print(f"type: {type(elt)}")
# Out:
# idx: -1
# elt: ['Hello', 'HSRW', '!']
# type: <class 'list'>

# %%
myList[1]=333

# %%
myList
# Out:
# [8, 333, 4.0, 'bla', ['Hello', 'HSRW', '!']]

# %% [markdown]
# #### Dictionary

# %%
myDict = {}

# %%
type(y(x))
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# function

# %%
myDict["key"] = "super value"
myDict["y1"] = y1
myDict["myFun"] = y

# %%
myDict["myFun"](5,10,1e6)
# Out:
# 1000175.0

# %%
myDict = { "hello":"hallo", "fantastic":myList}

# %%
print(myDict)
# Out:
# {'hello': 'hallo', 'fantastic': [8, 'bla', ['Hello', 'HSRW', '!']]}

# %%
myDict["fantastic"][-1][1]
# Out:
# 'HSRW'

# %%
list(myDict.values())
# Out:
# ['hallo', [8, 'bla', ['Hello', 'HSRW', '!']]]

# %%
list(myDict.values())[-1][-1][1]
# Out:
# 'HSRW'

# %% [markdown]
# ### Array, list, tuple slicing (chunk)

# %%
type(myList)
# Out:
# list

# %% [markdown]
# ### Dictionary of Curves ###

# %%
type(D["A"][3])
# Out:
# numpy.float64

# %%
D={}
D["A"]=y(x)
D["B"]=y(x,-10)
D["wow"]=y(x,-20)

# %%
for key in D:
    print("****************************************************")
    print(f"key: {key}")
    print(D[key])
# Out:
# ****************************************************
# key: A
# [-1.2500000e+02 -1.1059200e+02 -9.7336000e+01 -8.5184000e+01
#  -7.4088000e+01 -6.4000000e+01 -5.4872000e+01 -4.6656000e+01
#  -3.9304000e+01 -3.2768000e+01 -2.7000000e+01 -2.1952000e+01
#  -1.7576000e+01 -1.3824000e+01 -1.0648000e+01 -8.0000000e+00
#  -5.8320000e+00 -4.0960000e+00 -2.7440000e+00 -1.7280000e+00
#  -1.0000000e+00 -5.1200000e-01 -2.1600000e-01 -6.4000000e-02
#  -8.0000000e-03  8.7581154e-44  8.0000000e-03  6.4000000e-02
#   2.1600000e-01  5.1200000e-01  1.0000000e+00  1.7280000e+00
#   2.7440000e+00  4.0960000e+00  5.8320000e+00  8.0000000e+00
#   1.0648000e+01  1.3824000e+01  1.7576000e+01  2.1952000e+01
#   2.7000000e+01  3.2768000e+01  3.9304000e+01  4.6656000e+01
#   5.4872000e+01  6.4000000e+01  7.4088000e+01  8.5184000e+01
#   9.7336000e+01  1.1059200e+02  1.2500000e+02]
# ****************************************************
# key: B
# [-7.5000000e+01 -6.2592000e+01 -5.1336000e+01 -4.1184000e+01
#  -3.2088000e+01 -2.4000000e+01 -1.6872000e+01 -1.0656000e+01
#  -5.3040000e+00 -7.6800000e-01  3.0000000e+00  6.0480000e+00
#   8.4240000e+00  1.0176000e+01  1.1352000e+01  1.2000000e+01
#   1.2168000e+01  1.1904000e+01  1.1256000e+01  1.0272000e+01
#   9.0000000e+00  7.4880000e+00  5.7840000e+00  3.9360000e+00
#   1.9920000e+00 -4.4408921e-14 -1.9920000e+00 -3.9360000e+00
#  -5.7840000e+00 -7.4880000e+00 -9.0000000e+00 -1.0272000e+01
#  -1.1256000e+01 -1.1904000e+01 -1.2168000e+01 -1.2000000e+01
#  -1.1352000e+01 -1.0176000e+01 -8.4240000e+00 -6.0480000e+00
#  -3.0000000e+00  7.6800000e-01  5.3040000e+00  1.0656000e+01
#   1.6872000e+01  2.4000000e+01  3.2088000e+01  4.1184000e+01
#   5.1336000e+01  6.2592000e+01  7.5000000e+01]
# ****************************************************
# key: wow
# [-2.5000000e+01 -1.4592000e+01 -5.3360000e+00  2.8160000e+00
#   9.9120000e+00  1.6000000e+01  2.1128000e+01  2.5344000e+01
#   2.8696000e+01  3.1232000e+01  3.3000000e+01  3.4048000e+01
#   3.4424000e+01  3.4176000e+01  3.3352000e+01  3.2000000e+01
#   3.0168000e+01  2.7904000e+01  2.5256000e+01  2.2272000e+01
#   1.9000000e+01  1.5488000e+01  1.1784000e+01  7.9360000e+00
#   3.9920000e+00 -8.8817842e-14 -3.9920000e+00 -7.9360000e+00
#  -1.1784000e+01 -1.5488000e+01 -1.9000000e+01 -2.2272000e+01
#  -2.5256000e+01 -2.7904000e+01 -3.0168000e+01 -3.2000000e+01
#  -3.3352000e+01 -3.4176000e+01 -3.4424000e+01 -3.4048000e+01
#  -3.3000000e+01 -3.1232000e+01 -2.8696000e+01 -2.5344000e+01
#        -2.1128000e+01, -1.6000000e+01, -9.9120000e+00, -2.8160000e+00,
#         5.3360000e+00,  1.4592000e+01,  2.5000000e+01])])

# %%
D["new curve"] = y(x,-30,100)

# %%
fig2, ax2 = plt.subplots(1,1,figsize=(4,3),dpi=136)
ax2.plot(x,D["A"])
ax2.plot(x,D["B"])
ax2.plot(x,D["wow"])
plt.show()

# %%
fig3, ax3 = plt.subplots(1,1,figsize=(4,3),dpi=136)
for key in D:
    ax3.plot(x,D[key])

ax3.legend(D.keys()) 

plt.show()

# %% [markdown]
# ### Array of Curves ###

# %%
Y = np.array([y1,y2,y3])
X = np.array([x,x,x])

# %%
print(Y.shape)
(m,n) = Y.shape
print("Y, number of rows:    %4d" % m)
print("Y, number of columns: %4d" % n)
# Out:
# (3, 51)
# Y, number of rows:       3
# Y, number of columns:   51

# %%
# plotting one curve per column 
fig4, ax4 = plt.subplots(1,1,figsize=(4,3),dpi=136)
ax4.plot(X,Y,".-") # Just one plot command creating 51 curves à 3 points
plt.show()

# %% [markdown]
# **Plot Transposed Y**

# %%
print(X.T.shape)
(m,n) = X.T.shape
print("Y.T, number of rows:    %4d" % m)
print("Y.T, number of columns: %4d" % n)
# Out:
# (51, 3)
# Y.T, number of rows:      51
# Y.T, number of columns:    3

# %%
# plotting one curve per column
fig5, ax5 = plt.subplots(1,1,figsize=(4,3),dpi=136)
ax5.plot(X.T,Y.T,".-") # Just one plot command creating 3 curves à 51 points
plt.show()

# %% [markdown]
# ## Ex 2: Define a function with parameters and plot
#
# Analog to the example above create an x-vector from -3 to 3 in steps 0.1 (closed interval).
#
# Define the function $f(x,x_0,y_0,c)=c(x-x_0)^2+y_0$. The parameters should have the default values $x_0=0 , y_0=0, c=1$.
#
# Create the following plot:
# <br>
# <img src="parabola_01.png" width="400">
# <br>
# Find the right parameters e.g. by trying or calculating or the method "new functions from old functions".

# %%
# complete
def f(x,...):
    return ...

# %%
# complete
x = np.arange(...)
y = f(x,...)

# %%
# complete
fig6, ax6 = plt.subplots(1,1,figsize=(4,4),dpi=136)
ax6.plot(x,y,".-")
ax6.grid(True)
ax6.set_xlim(...)
ax6.set_ylim(...)
ax6.legend([r"$f(x)=c(x-x_0)^2+y_0$"])
plt.show()

# %% [markdown]
# ## Ex. 3: Plot some points of the function to emphasize the points.
#
# Create the following plot:
# <br>
# <img src="parabola_02.png" width="400">

# %%
# complete
xs=np.arange(...)
ys=...

# %%
fig7, ax7 = plt.subplots(1,1,figsize=(4,4),dpi=136)
ax7.plot(x,y,"-") 
ax7.plot(...) 
[...]
plt.show()

# %% [markdown]
# ## Ex. 4: Create a family of curves and plot
#
# Look at the following code:

# %%
M = np.array([[0,0,1],[0,1,1],[1,1,1],[1,0,1]])
nrows=M.shape[0]
print(nrows)

# %%
fig8, ax8 = plt.subplots(1,1,figsize=(4,4),dpi=136)
for i in range(nrows):
    x0,y0,c = M[i]
    y = f(x,x0,y0,c)
    ax8.plot(x,y)

ax8.grid(True)
ax8.set_xlim([-1,3])
ax8.set_ylim([-1,3])
plt.show()

# %% [markdown]
# **Now create a plot with the following family of curves:**
# <br>
# <img src="parabola_03.png" width="400">

# %%
# complete
M = np.array([...])
nrows=M.shape[0]
print(nrows)

# %%
# complete
fig9, ax9 = plt.subplots(1,1,figsize=(4,4),dpi=136)
[...]
plt.show()
