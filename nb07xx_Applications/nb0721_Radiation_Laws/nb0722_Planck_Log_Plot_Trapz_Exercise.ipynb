# %% [markdown]
# # Radiation Laws #
#
#
# ## Planck's Black Body Function ##
#
#
# $$ b_\lambda(T, \lambda) = \frac{c_1}{\lambda^5\left( \exp\left(\frac{c_2}{\lambda T}\right)-1 \right)}$$
#
# $$ \lim_{\lambda \rightarrow 0} b_\lambda(T, \lambda) = 0$$
#
# $$ b_\lambda(T, 0\,\mathrm{nm}) = 0 \mathrm{\frac{W}{m^2\,nm}}$$
#
#
# $$ 𝑐_1=2\pi h c^2 = 3.741\cdot 10 ^{−16} \mathrm{Wm^2} $$
#
# $$ 𝑐_2=\frac{hc}{k} = 1.438\cdot 10^{−2} \mathrm{m\cdot K} $$
#
# ## Stefan-Boltzmann Law ##
#
# $$
# \begin{eqnarray}
# e_T(T) & = & \int_0^{+\infty} b_\lambda(\lambda,T) d\lambda = \sigma T^4 \\
# \sigma & = & 5.67037\cdot 10^{-8} \mathrm{\frac{W}{m^2 K^4}}
# \end{eqnarray}
# $$
#
# ## Wien's Displacement Law ##
#
# $$ \lambda_\mathrm{max} = \frac{2898\;\mathrm{\mu m\cdot K}}{T} $$

# %% [markdown]
# # Physical Constants related to Radiation

# %%
# Import constants and rename them

#import scipy.constants as sc
#k = sc.k
#h = sc.h
#c = sc.c
#sigma = sc.sigma
#pi = sc.pi

# Simpler: 
from scipy.constants import pi, c, h, k, sigma

print("PYSICAL CONSTANTS")
print("----------------------")
print("Pi:                   pi = %g " % pi)
print("Vac. speed of light:   c = %g m/s" % c)
print("Plank's constant:      h = %g Js" % h)
print("Boltzmann:             k = %g J/K" % k)
print("Stefan-Boltzmann:  sigma = %g W/(m^2 K^4)" % sigma)
# Out:
# PYSICAL CONSTANTS
# ----------------------
# Pi:                   pi = 3.14159
# Vac. speed of light:   c = 2.99792e+08 m/s
# Plank's constant:      h = 6.62607e-34 Js
# Boltzmann:             k = 1.38065e-23 J/K
# Stefan-Boltzmann:  sigma = 5.67037e-08 W/(m^2 K^4)

# %% [markdown]
# #### Alternative way of importing

# %%
#from scipy.constants import h
import scipy.constants as sc
print(f"h = {sc.h:.4g} W/(m^2 K^4)")
# Out:
# h = 6.626e-34 W/(m^2 K^4)

# %% [markdown]
# # Planck's Law of Black Body Radiation #

# %% [markdown]
# ### Planck's Curve of Black Body Radiation

# %%
# This function causes problems for small lambda.
def planck(T,lam):
    from scipy.constants import k,h,c,pi
    from numpy import exp
    #s = sigma
    # here we could also import all the constants from scipy.constants
    #k = 1.38054e-23 # J/K
    #h = 6.6256e-34 # Js
    #s = 5.6703e-8 # W/(m^2 K^4)
    #c = 2.997e8 # m/s
    c1= 2*pi*c**2*h
    c2= c*h/k
    el = c1/(lam**5*(exp(c2/(lam*T))-1))
    return(el)

# %% [markdown]
# ### Wien's Displacement Law

# %%
def wien(T):
    lam_max = 2898e-6/T # 2898 mu m * K
    return(lam_max)

# %% [markdown]
# ### Imports and Default Plot Settings

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.rcParams['figure.figsize'] = (4,3) # Set the default figure size. You have to calibrate DPI
plt.rcParams['figure.dpi'] = 136 # depends on your system
#mpl.rcParams['figure.figsize'] = (6,4) # Set the default figure size. You have to calibrate DPI
#mpl.rcParams['figure.dpi'] = 300 # depends on your system
plt.show()

# %% [markdown]
# ## Plotting the Planck Curve ##

# %% [markdown]
# ### Definition of the wavelength range for evaluating the Planck curve
#
# $1\; \mathrm{nm} \le \lambda \lt 10000\; \mathrm{nm}$

# %%
lam=np.arange(1,10000)*1e-9 # lam = 0 nm causes problems in the function planck()
lam
# Out:
# array([1.000e-09, 2.000e-09, 3.000e-09, ..., 9.997e-06, 9.998e-06,
#        9.999e-06])

# %% [markdown]
# ### Choose the Temperature!

# %%
#fig1 = plt.figure(1)
#ax1 = fig1.add_subplot(111)

T = 6000 # K
#T = 5525 # K

# %% [markdown]
# ### Calulate!

# %%
e_lam = planck(T,lam)
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %% [markdown]
# ### Plot!

# %%
fig1, ax1 = plt.subplots(1,1, facecolor='lightgrey', edgecolor='k')

ax1.plot(lam*1e9,e_lam*1e-9)
ax1.set_xlim(np.array([0,3000])) # nm
plt.grid(True)

ax1.set_title(r'Spectral Exitance of Ideal Black Body')
ax1.set_xlabel(r'Wavelength $\lambda \;\;/\;\; \mathrm{nm}$')
ax1.set_ylabel(r'Spectral exitance $e_{\lambda} \;\;/\;\; \mathrm{W m^{-2} nm^{-1}}$')

ax1.legend([f"T={T} K"]) # dynamic legend!
plt.show()

# %% [markdown]
# #### A note on light grey figure background (facecolor) above
#
# <font color=green>
#     Hey! I just learnt how to change font colors from here:
# </font>
#
# https://ingeh.medium.com/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed
#
# `<font color=blue|red|green|pink|yellow>Text</font>`
#
# The background color of the figure above is good for inline plotting but not for printing! You would waste a lot of color (and/or black) ink when you print it.

# %% [markdown]
# ### Compare five curves for different temperatures.

# %%
# Five curves for five temperatures
T1 = 6000
e1=planck(T1,lam)
T2 = 3000
#T2 = 5525
e2=planck(T2,lam)
T3 = 1500
e3=planck(T3,lam)
T4 = 750
e4=planck(T4,lam)
T5 = 375
e5=planck(T5,lam)
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %%
fig2, ax2 = plt.subplots(1,1)

ax2.plot(lam*1e9,e1*1e-9)
ax2.plot(lam*1e9,e2*1e-9)
ax2.plot(lam*1e9,e3*1e-9)
ax2.plot(lam*1e9,e4*1e-9)
ax2.plot(lam*1e9,e5*1e-9)

ax2.grid(True)

ax2.set_title(r'Spectral Exitance of Thermal Radiators')
ax2.set_xlabel(r'Wavelength $\lambda \;\;/\;\; \mathrm{nm}$')
ax2.set_ylabel(r'Spectral exitance $e_{\lambda} \;\;/\;\; \mathrm{W m^{-2} nm^{-1}}$')

ax2.legend(['6000K','3000K','1500K','750K','375K'])

plt.show()

#plt.savefig('planck_IPython_V001.png', bbox_inches='tight')
#plt.show()
#plt.savefig('planck_IPython_V001.png')

# %% [markdown]
# ### Plot with log scale on y-axis and plot maxima based on Wien.

# %%
T_wien = np.array([6000,3000,1500,750,375, 306])
lam_wien = wien(T_wien)

for (T_wien_elt, lam_wien_elt) in zip(T_wien,lam_wien):
    print(f"{T_wien_elt:6.1f} K -> {lam_wien_elt*1e9:7.1f} nm")
# Out:
# 6000.0 K ->   483.0 nm
# 3000.0 K ->   966.0 nm
# 1500.0 K ->  1932.0 nm
#  750.0 K ->  3864.0 nm
#  375.0 K ->  7728.0 nm
#  306.0 K ->  9470.6 nm

# %%
fig3, ax3 = plt.subplots()

ax3.semilogy(lam*1e9,e1*1e-9)
lam_max_T1 = wien(T1)
ax3.plot(lam_max_T1*1e9, planck(T1,lam_max_T1)*1e-9, "r*")

ax3.semilogy(lam*1e9,e2*1e-9)
lam_max_T2 = wien(T2)
ax3.plot(lam_max_T2*1e9, planck(T2,lam_max_T2)*1e-9, "r*")

ax3.semilogy(lam*1e9,e3*1e-9)
lam_max_T3 = wien(T3)
ax3.plot(lam_max_T3*1e9, planck(T3,lam_max_T3)*1e-9, "r*")

ax3.semilogy(lam*1e9,e4*1e-9)
lam_max_T4 = wien(T4)
ax3.plot(lam_max_T4*1e9, planck(T4,lam_max_T4)*1e-9, "r*")

ax3.semilogy(lam*1e9,e5*1e-9)
lam_max_T5 = wien(T5)
ax3.plot(lam_max_T5*1e9, planck(T5,lam_max_T5)*1e-9, "r*")

ax3.grid(True)

ax3.set_ylim([1e-3,1e6])

ax3.set_title(r'Spectral Exitance of Thermal Radiators')
ax3.set_xlabel(r'Wavelength $\lambda \;\;/\;\; \mathrm{nm}$')
ax3.set_ylabel(r'Spectral exitance $e_{\lambda} \;\;/\;\; \mathrm{W m^{-2} nm^{-1}}$')

#ax3.legend(['6000K','max(6000K)','3000K','1500K','750K','375K'])
plt.show()

# %% [markdown]
# # Integration of Planck's Function of Black Body Radiation
#
# $e_\lambda(T,\lambda)$ is integrable (i.e. the integral converges) on the interval $[0,\infty]$ but we cannot write down an antiderivative in closed form.
#
# $$ \lim_{\lambda_1 -> \infty} \int_0^{\lambda_1} e_\lambda(T, \lambda) d\lambda = \sigma T^4$$

# %% [markdown]
# ## Trapezoid Rule ##

# %% [markdown]
# Integration (in 1D) can be interpreted as the determination of the area under a curve ("well-behaving" graph of a function). If segments of the curve are below zero then their area contribution is counted negative.
#
# To determine the integral numerically the area between the function graph and the x-axis is approximated by a finite number of primitive geometric figures such as rectangles or trapezoids. The sum of all the geometric figures' areas yields the approximated area.
#
# The more geometric figures are used the finer the discretization of the area becomes and the accuracy of the areal approximation increases. This area approaches the "real" integral more and more. The accuracy limit is determined by the number representation of the computer used.
#
# The Trapezoid rule is a numerical interpolation method utilizing trapezoids to approximate the area. The area of a single trapezoid can be calculated easily.
#
# The areas of $n$ trapezoids $A_1, \, \ldots \, A_n$ are:
#
#
# $$
# \begin{eqnarray}
# A_1 &=& (x_1 - x_0) \frac{1}{2} (y_1 + y_0) \\
# A_2 &=& (x_2 - x_1) \frac{1}{2} (y_2 + y_1) \\
# & \vdots & \\
# A_{n} &=& (x_n - x_{n-1}) \frac{1}{2} (y_n + y_{n-1}) \\
# \end{eqnarray}
# $$
#
# With $y_k = f(y_k)$ .
#
# The $n$ trapezoids are determined by their $n+1$ sides at the supporting points $x_0, x_1, \ldots x_n$.
#
# To simplify the problem the trapezoids are chosen such that they have the same width.
# <br>
# Thus the $n+1$ supporting points (the $x_k$) are **<font color=red>equidistant</font>**, i.e.:
#
# $$x_k - x_{k-1} = h \mathrm{const.}  \;,\; k\in \{1, \ldots n\} $$.
#
# The total area $A$ of all trapezoids is:
# $$ A = \sum_{k=1}^{n} A_k = \sum_{k=1}^{n} \frac{1}{2}h\,(y_{k-1}+y_k) = \frac{1}{2}h\sum_{k=1}^{n} (y_{k-1}+y_k) $$
#
# The last sum reads:
#
# $$
# \begin{eqnarray}
# \sum_{k=1}^{n} (y_{k-1} +y_{k}) &=& \\
# & = & (y_0 + y_1) + (y_1 + y_2) + \ldots + (y_{n-2} + y_{n-1}) + (y_{n-1} + y_n) = \\
# & = & y_0 + y_n + 2\sum_{k=1}^{n-1}y_k = \\
# & = & 2y_0 + 2y_n - y_0 -y_n + 2\sum_{k=1}^{n-1}y_k = \\
# &= & 2\sum_{k=0}^{n}y_k - (y_0 + y_n)
# \end{eqnarray}
# $$
#
# Finally the trapezoid rule reads:
# $$
# \begin{eqnarray}
# A & = & \frac{1}{2}h\,\left( 2\sum_{k=0}^{n}y_k - (y_0 + y_n) \right) = h\left(\sum_{k=0}^{n}y_k -\frac{1}{2}(y_0 + y_n)\right) \\
# y_k & = & f(y_k) \\
# \Rightarrow \; A & = & h\left(\sum_{k=0}^{n}f(x_k) -\frac{1}{2}\left(f(x_0) + f(x_n)\right)\right)
# \end{eqnarray}
# $$

# %%
# Trapezoid rule

def integrate(f, a, b, n=100):
    """
    Integrate f from a to b,
    using the Trapezoidal rule with n trapazoids.
    """
    x = np.linspace(a, b, n+1)    # Coordinates of the intervals
    h = x[1] - x[0]            # Interval spacing
    I = h*(np.sum(f(x)) - 0.5*(f(a) + f(b)))
    return I

# %%
help(integrate)
# Out:
# Help on function integrate in module __main__:
#
# integrate(f, a, b, n=100)
#     Integrate f from a to b,
#     using the Trapezoidal rule with n trapazoids.

# %%
def plot_trapz(f, xs, ax, sc_x=1e9, sc_y=1e-9, color="y"):
    """
    Plot trapezoids based on function f evaluated at supporting points xs.
    ax is an axis element of a matplotlib.pyplot subplot, i.e. of type matplotlib.axes
    sc_x and sc_y are scaling factors for plotting used for unit conversion (e.g. m -> nm)
    color is the trapezoid plot color.
    """    
    
    xp = xs*sc_x
    yp = f(xs)*sc_y

    xi = [xp,xp]   # multiple line plot
    yi = [yp*0,yp] # multiple line plot
    
    ax4.plot(xp,yp*0,color+".-")
    ax4.plot(xp,yp,color+".-")
    ax4.plot(xi,yi,color+"-")

# %%
help(plot_trapz)
# Out:
# Help on function plot_trapz in module __main__:
#
# plot_trapz(f, xs, ax, sc_x=1000000000.0, sc_y=1e-09, color='y')
#     Plot trapezoids based on function f evaluated at supporting points xs.
#     ax is an axis element of a matplotlib.pyplot subplot, i.e. of type matplotlib.axes
#     sc_x and sc_y are scaling factors for plotting used for unit conversion (e.g. m -> nm)
#     color is the trapezoid plot color.

# %% [markdown]
# ### Define temperature and integrate manually

# %%
T = 6000

# %%
fig4, ax4 = plt.subplots()

sc_x = 1e9  # scale factor x-axis, m -> nm (1e9 nm are in 1 m)
sc_y = 1e-9 # scale factor y-axis, W/(m²m) -> W/(m²nm)

ax4.plot(lam*sc_x,planck(T,lam)*sc_y,"b")

# supporting points, sampling points
lam_sample = np.array([100,500,1000,1300,2000,4000])*1e-9 # 100nm, 500nm, 1000nm ... in m

# Transform planck(T, lam) into a function pl(lam) for a fixed temperature  
# pl(lam) = planck(T=6000,lam): reduce the 2-argument function planck to a 1-argument function pl with a fixed temp

pl = lambda x: planck(T,x) # take the T which is already defined
plot_trapz(pl, lam_sample, ax4, color="y")

ax4.set_xlim(np.array([0,5000]))
ax4.grid(True)

ax4.set_title(r'Spectral Exitance of Thermal Radiators')
ax4.set_xlabel(r'Wavelength $\lambda \;\;/\;\; \mathrm{nm}$')
ax4.set_ylabel(r'Spectral exitance $e_{\lambda} \;\;/\;\; \mathrm{W m^{-2} nm^{-1}}$')

ax4.legend([f"T={T}K","Trapezoids"])
plt.show()
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %% [markdown]
# $$
# \begin{eqnarray}
# e_T & = & \sigma T^4 = \\
# & = & 5.67\cdot10^{-8} \mathrm{\frac{W}{m^2 K^4}} \cdot (6000\;\mathrm{K})^4 = \\
# & = & 5.67\cdot10^{-8} \mathrm{\frac{W}{m^2 K^4}} \cdot 6000^4 \; \mathrm{K}^4 = \\
# & = & 73.5\;\mathrm{MW}
# \end{eqnarray}
# $$

# %%
sigma = 5.67e-8 # W / (m^2 K^4)
T = 6000 # K
# T = 5525
# T = 33 + 273 # 33°C in K
eT = sigma*T**4 # W / m^2
print(f"The total exitance of a black body\nof temperature {T} K\nis {eT*1e-6:.1f} MW/m^2")
print("Typical power of power plant block is 100MW ... 750MW ... 1000MW")
# Out:
# The total exitance of a black body
# of temperature 6000 K
# is 73.5 MW/m^2
# Typical power of power plant block is 100MW ... 750MW ... 1000MW

# %% [markdown]
# ### Sampling points, support points

# %%
lam_s = np.array([100, 500, 1000, 1300, 2000, 4000])*1e-9 # in m
lam_s*1e9
# Out:
# array([ 100.,  500., 1000., 1300., 2000., 4000.])

# %%
e_lam_s = planck(T,lam_s) # W/(m^2 m) -> W/(m^2 nm)
e_lam_s*1e-9

for (lam, el) in zip(lam_s, e_lam_s):
    print(f"{lam*1e9:7.1f} nm -> {el*1e-9:7.1f} W/(m^2 nm)")
# Out:
#   100.0 nm ->     1.4 W/(m^2 nm)
#   500.0 nm -> 99767.3 W/(m^2 nm)
#  1000.0 nm -> 37415.0 W/(m^2 nm)
#  1300.0 nm -> 18923.5 W/(m^2 nm)
#  2000.0 nm ->  5047.2 W/(m^2 nm)
#  4000.0 nm ->   445.0 W/(m^2 nm)

# %%
A1 = ( 500 -  100) * 1/2 *     (1.4 + 99767.3) # W/m^2
A2 = (1000 -  500) * 1/2 * (99767.3 + 37415.0)
A3 = (1300 - 1000) * 1/2 * (37415.0 + 18932.5)
A4 = (2000 - 1300) * 1/2 * (18932.5 +  5047.2)
A5 = (4000 - 2000) * 1/2 *  (5047.2 +   445.0)
print(f"A1: {A1/1e6:6.2f} MW/m^2")
print(f"A2: {A2/1e6:6.2f} MW/m^2")
print(f"A3: {A3/1e6:6.2f} MW/m^2")
print(f"A4: {A4/1e6:6.2f} MW/m^2")
print(f"A5: {A5/1e6:6.2f} MW/m^2")

A = A1 + A2 + A3 +A4 + A5
print(f"A:  {A/1e6:6.2f} MW/m^2")

eT = sigma*T**4
print(f"eT: {eT/1e6:6.2f} MW/m^2")

d = (A - eT); r = d / eT
print(f"rel. error: {r*100:5.2f} %")

abs_error = A-eT # is it big or small? It depends!
rel_error = abs_error/eT # deviation in relation to the real value

print("The absolute error is %8.3g W/m²" % abs_error)
print("The relative error is %8.3f" % rel_error)
print("The relative error is %+7.2f %%" % (rel_error*100))
# Out:
# A1:  19.95 MW/m^2
# A2:  34.30 MW/m^2
# A3:   8.45 MW/m^2
# A4:   8.39 MW/m^2
# A5:   5.49 MW/m^2
# A:   76.59 MW/m^2
# eT:  73.48 MW/m^2
# rel. error:  4.22 %
# The absolute error is  3.1e+06 W/m²
# The relative error is    0.042
# The relative error is   +4.22 %

# %% [markdown]
# ## Manual integration by trapezoids

# %%
mylist = zip(lam_s*1e9, e_lam_s*1e-9)
for lam, e_lam in mylist:
#    print("%8.1f   %8.1f" % (lam, e_lam))
    print(f"| {lam:8.1f} nm | {e_lam:8.1f} W/(m²nm) |")
# Out:
# |    100.0 nm |      1.4 W/(m²nm) |
# |    500.0 nm |  99767.3 W/(m²nm) |
# |   1000.0 nm |  37415.0 W/(m²nm) |
# |   1300.0 nm |  18923.5 W/(m²nm) |
# |   2000.0 nm |   5047.2 W/(m²nm) |
# |   4000.0 nm |    445.0 W/(m²nm) |

# %% [markdown]
# ### What the students calculated in the 2020 Physics 2 class ###

# %%
# Results form the Students' trapezoid area calculations:
A1 = 19.97e6 # W/m
A2 = 34.3e6
A3 = 8.4e6
A4 = 8.4e6
A5 = 5.5e6
A = A1 + A2 +A3 + A4 + A5

T = 6000 # K
sigma = 5.67e-8 # W/(m^2 K^4)

eT = sigma * T**4

print ("Approximation (sum of trapezoids):  A = %.3g W/m²" % A)
print ("Stefan-Boltzmann:                  eT = %.3g W/m²" % eT)
# Out:
# Approximation (sum of trapezoids):  A = 7.66e+07 W/m²
# Stefan-Boltzmann:                  eT = 7.35e+07 W/m²

# %%
test = np.array([1,2,3,4,5])
np.cumsum(test)
# Out:
# array([ 1,  3,  6, 10, 15], dtype=int32)

# %% [markdown]
# ## Another Trapezoid Rule for Listed Values

# %%
# Trapezoid rule

def integrate_listed_val(x,y):
    
    xL = x[:-1]
    yL = y[:-1]
    
    xR = x[1:]
    yR = y[1:]
    
    Dx = xR - xL
    
    My = 1/2*(yR + yL)
    
    Ak = Dx*My
    
    I = np.sum(Ak)
    
    C     = x*0 # a vector of len(x) initialized with zeros.    
    C[0]  = 0
    C[1:] = np.cumsum(Ak) 

    return I, C

# %%
lam = np.arange(1,10000)*1e-9
T1 = 6000
T2 = 5000

# %%
I1, C1 = integrate_listed_val(lam,planck(T1,lam)/(sigma*T1**4))
I2, C2 = integrate_listed_val(lam,planck(T2,lam)/(sigma*T2**4))
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %%
fig5 = plt.figure(figsize=(6,6), dpi = 136)
gs5 = fig5.add_gridspec(2, 1, hspace=0)
(ax51, ax52) = gs5.subplots(sharex = True)

ax51.set_ylabel(r"Spec. Exit. $e_\lambda$ in $ \mathrm{ \frac{W}{m^2 nm}}$")
ax51.plot(lam*1e9,planck(T1,lam)*1e-9)
ax51.plot(lam*1e9,planck(T2,lam)*1e-9)
ax51.set_xlim(0,3000)
ax51.grid(True)
ax51.legend([f"{T1} K", f"{T2} K"])
#ax51.set_xticklabels([])

ax52.set_ylabel("Areal Fraction")
ax52.plot(lam*1e9,C1)
ax52.plot(lam*1e9,C2)
ax52.set_xlim(0,3000)
ax52.grid(True)
#ax52.legend([f"{T1} K", f"{T2} K"])
ax52.set_xlabel(r"Wavelength $\lambda$ in nm")

plt.show()
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %%
fig6, ax6 = plt.subplots(1,1,figsize=(6,4), dpi = 136)
ax6.plot(lam*1e9,C1)
ax6.plot(lam*1e9,C2)
ax6.set_ylabel("Areal Fraction")
ax6.set_xlim(0,3000)
ax6.grid(True)
plt.show()

# %% [markdown]
# ## Yet another trapezoid rule for defined functions but returning also support points and cumulative sum.

# %% [markdown]
# The following function `integrate2` is a mixture of the functions `integrate(...)` and `integrate_listed_val`.
#
# Here the function to be integrated (integrand) as well as the integration limits are passed to the function `integrate2` as with `integrate`. The difference is that `integrate2` not only returns the integral vom a to b but also all support points xs in creates internally as well as the cummulative sum.

# %%
# Trapezoid rule

def integrate2(f, a, b, n=100):
    """
    (I, C, xs) = integrate2(f, a, b, n=100)
    Integrate f from a to b using the Trapezoidal rule with n trapazoids.
    The function returns: 
    xs: n+1 support points defining the lower corners of trapezoids, xs[0] = a, xs[n] = b 
    C: integral vector (n+1 dim.) containing the cumulative sum of trapesoids, i.e. all integrals from a to xs(k) for all k in {0,1,...n}
    I: Complete integral from a to b, sum over all trapezoids, I = C[n]
    """
    xs = np.linspace(a, b, n+1)  # Support points defining the lower corners of trapezoids 
    ys = f(xs)

    xL = xs[:-1]
    yL = ys[:-1]
    
    xR = xs[1:]
    yR = ys[1:]
    
    Dx = xR - xL
    
    My = 1/2*(yR + yL)
    
    Ak = Dx*My
    
    I= np.sum(Ak)
    
    C     = xs*0 # a vector of len(x) initialized with zeros.    
    C[0]  = 0
    C[1:] = np.cumsum(Ak) 

    return I, C, xs

# %% [markdown]
# ## Exercise 1: Implement the integration of the normalized Plank curve.

# %% [markdown]
# Implement the integration of the normalized Plank curve:
#
# $$
# F(x) = \int_0^{x_u} \frac{c_1}{\sigma x^5 \left( \exp\left(\frac{c_2}{x}\right)-1\right)}dx
# $$
#
# with upper integration limit $x_u = \lambda_u\cdot T$ and $\lambda_u$ being the wavelength up to which the Planck curve is to be integrated.

# %% [markdown]
# ### Step 1: Define integrand $g(x)$
#
# The integrant of the above integral is
#
# $$
# g(x) = \frac{c_1}{\sigma x^5 \left( \exp\left(\frac{c_2}{x}\right)-1\right)}
# $$
#
# Implement it in Python: `def g(x): ...`

# %%
# def g(x):
#     ...

# %% [markdown]
# ### Step 2: Integrate $g(x)$
#
# Integrate $g(x)$ from $0$ to upper integration limits $x_u \in ( 0, \, 0.01, \, 0.02, \, 0.03, \ldots 25.00)\cdot 10^{-3}  \mathrm{m\cdot K} $ by means of the function `integrate_listed_val(x,y)`

# %%
# x = np.arange(...)
# y = g(x)
# (I, F) = integrate_listed_val(x,y)

# %% [markdown]
# ### Step 3: Plot $F(x)$
#
# Plot $F(x)$.

# %%
# fig8, ax8  =

# %% [markdown]
# Compare the results to pages 41 and 42 of https://teawiki.net/lib/exe/fetch.php?media=phy2:topics:radiation_laws:ee_phy2_p0020_radiation_laws_2020-05-07_v002_pres.pdf
# <br>
# Do they match?

# %% [markdown]
# ### Step 4: Determine the proportion of exitance (fractional area) for a given wavelength interval.
#
# Assume the black body has a surface temperature of $T =  306\, \mathrm{K}$. What is the total exitance (Stefan-Boltzmann)?
#
# What is the share (percentage) of radiant power density (exitance) for the intervals $[400, 700]\;\mathrm{nm}$ and $[5000, 15000]\;\mathrm{nm}$?
#
# Determine the four upper integration limits $x_u = \lambda \cdot T$ for the four wavelengths.
#
# Create appropriate vectors (numpy array) of support points $x = \big(x_0 (= 0), x_1, x_2, \ldots \, x_n (= x_u)\big)$ to perform the integration of $y = g(x)$ using `I = integrate_listed_val(x,y)` like you have done before.
#
# Subtract the integrals, e.g. $I(700\,\mathrm{nm}) - I(400\,\mathrm{nm})$ and  $I(15000\,\mathrm{nm}) - I(5000\,\mathrm{nm})$, respectively.
#
# What do you observe?

# %% [markdown]
# ## Exercise 2: Integrate the Planck curve directly without normalization.
#
# This time use the function `integrate(f, a, b, n)` to integrate the Planck black body function from $a$ to $b$ directly. The Problem is, that the Planck function has two arguments, i.e. $\lambda$ and $T$!
#
# If you look at the implementation of `integrate(f, a, b, n)` you see that $f(x)$ is called, i.e. the function `f` we are passing as the first argument to `integrate(f, ...)` is fed with only one argument inside `integrate()`. Locally inside `integrate()`it is named `x` but in fact it contains the wavelength vector. Passing a second argument is not envisaged.
#
# To overcome this problem we have to create another function from `planck()` with just one argument for a fixed temperature.
#
# **Example:**

# %%
# only one required argument, T is set to its default value. You have to adjust it if you want to use a different temperature.
T = 5800
def pl(lam, T=5800):
    return planck(T, lam)

# %%
lam_l = 1e-9 # lower limit (1nm)
lam_u = 1e-4 # Upper limit (100um)
n = 10000

# %%
I = integrate(pl, lam_l, lam_u, n)
# Out:
# <ipython-input-3-c4921daf6450>:13: RuntimeWarning: overflow encountered in exp
#   el = c1/(lam**5*(exp(c2/(lam*T))-1))

# %%
eT = sigma*T**4

# %%
# Compare
print("Total Exitance")
print(f"Precise integral:   {eT/1e6:10.4f} MW/(m^2 nm)")
print(f"Numerical integral: {I/1e6:10.4f} MW/(m^2 nm)")
# Out:
# Total Exitance
# Precise integral:      64.1645 MW/(m^2 nm)
# Numerical integral:    64.1687 MW/(m^2 nm)

# %% [markdown]
# ### Task 1: Integrate the black body curve for 500 K from 400 to 700 nm.
#
# How large is the radiant power density $e_\mathrm{vis}$ for a body of 500 K in the visible wavelength band? Use the unit $\mathrm{W/(m^2 nm})$. You need to change the default temperature value in the function `pl(...)`.
#
# Divide this value by the total exitance $e_T(500\,\mathrm{K})$ to get the percentage on the total exitance.

# %% [markdown]
# ### Task 2: Increase temperature ...
#
# How far do you have to increase the temperature such that $e_\mathrm{vis} / e_T \approx 10\% $? Solve this by trial and error. Play with different temperatures until you come close to the 10%.

# %% [markdown]
# ## Exercise 3: Inverse Problem
#
# Be the temperature of black body 5800 K. Up to which wavelength to you have to integrate to cover 70% of the total exitance? Play with the upper integration limit until you come close to 70%.
#
# Try out two ways:
#
# 1. Integrate Planck directly and diving by total exitance (Stefan-Boltzmann). Tune the upper integration limit util you get approx. 70%.
# 1. Integrate $g(x)$. Tune the upper integration limit $x_u$ until you get approx. 70%. From $x_u$ and the given $T$ determine $\lambda_u$.

# %% [markdown]
# ## Side Notes

# %% [markdown]
# ### MathJax
# Im case you want to learn more about **mathematical typesetting with MathJax** (works like $\LaTeX$) go to
# <br>
# https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference

# %% [markdown]
# ### How to control the font style
#
# The markdown expression
# <br>
# `<span style="color:gold; font-family:Arial; font-size:1.4em;"> Do we really need text colors? </span>`
# <br>
# leads to:
# <br>
# <span style="color:gold; font-family:Arial; font-size:1.4em;"> Do we really need text colors? </span>
#
# Changing the font style will cause problems when exporting the notebook to $\LaTeX$.
